# %% [markdown]
# # DBSCAN Clustering

# %%
import pandas as pd
import numpy as np
from bokeh.io import output_notebook, show, curdoc, push_notebook
from bokeh.models import ColumnDataSource,HoverTool,ColorBar
from bokeh.plotting import figure, show, output_notebook
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt
from bokeh.layouts import layout
from bokeh.layouts import row
from ipywidgets import interact
import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, interact_manual, IntSlider

output_notebook()

data = pd.read_csv('Wholesale customers data.csv')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="bd569864-9647-4c72-86a5-4f0056818e94">Loading BokehJS ...</span>
#     </div>

# %%
data = data.drop('Channel',axis=1)
data = data.drop('Region',axis=1)
data.head(10)
# Out:
#    Fresh   Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0  12669   9656     7561     214              2674        1338
# 1   7057   9810     9568    1762              3293        1776
# 2   6353   8808     7684    2405              3516        7844
# 3  13265   1196     4221    6404               507        1788
# 4  22615   5410     7198    3915              1777        5185
# 5   9413   8259     5126     666              1795        1451
# 6  12126   3199     6975     480              3140         545
# 7   7579   4956     9426    1669              3321        2566
# 8   5963   3648     6192     425              1716         750
# 9   6006  11093    18881    1159              7425        2098

# %% [markdown]
# ### Dataset loaded into dataframe

# %% [markdown]
# ### Creating the DBSCAN model, bokeh figure and plotting circle glyphs

# %%
db = DBSCAN(eps=5000, min_samples=40)
db.fit(data[['Milk','Grocery']])
data['cluster'] = db.labels_

colormap = {-1: 'black', 0: 'red', 1: 'blue', 2: 'green', 3: 'yellow', 4: 'orange', 5: 'black', 6: 'navy', 7: 'pink'}
colors = [colormap[x] for x in data['cluster']]

p = figure(title = "Wholesale Customers Data", tools="hover,lasso_select,pan,wheel_zoom,box_zoom,reset,save")
p.xaxis.axis_label = 'Milk'
p.yaxis.axis_label = 'Grocery' 

x = data['Milk'].tolist()
y = data['Grocery'].tolist()

r = p.circle(x, y, color=colors, fill_alpha=0.2, size=10)

# %% [markdown]
# ### Defining method for updating plot based on user interaction

# %%
def update(X_Axis,Y_Axis,Radius,Minimum_Samples):
    rd = Radius
    mini = Minimum_Samples
    db_new = DBSCAN(eps=rd,min_samples=mini)
    db_new.fit(data[[X_Axis,Y_Axis]])
    data['cluster_updated'] = db_new.labels_

    colormap_new = {-1: 'black', 0: 'red', 1: 'blue', 2: 'green', 3: 'yellow', 4: 'orange', 5: 'black', 6: 'navy', 7: 'pink'}
    colors_new = [colormap_new[x] for x in data['cluster_updated']]
    
    x_new = data[X_Axis].tolist()
    y_new = data[Y_Axis].tolist()
        
    r.data_source.data['x'] = data[X_Axis]
    r.data_source.data['y'] = data[Y_Axis]
    p.xaxis.axis_label = X_Axis
    p.yaxis.axis_label = Y_Axis
    r.data_source.data['fill_color'] = colors_new
    r.data_source.data['line_color'] = colors_new
    
    push_notebook()

# %%
show(p, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="468fc14d-c2a2-48f4-91eb-8fac4caeff43"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("468fc14d-c2a2-48f4-91eb-8fac4caeff43");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("468fc14d-c2a2-48f4-91eb-8fac4caeff43");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '468fc14d-c2a2-48f4-91eb-8fac4caeff43' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"862a43b4-5b27-4ab6-9b73-9124fea0a7da":{"roots":{"references":[{"attributes":{"below":[{"id":"4b7a8e3c-8231-4af2-8b23-91295138e236","type":"LinearAxis"}],"left":[{"id":"ce2e7ce5-59df-4517-9b2b-13322a9a87de","type":"LinearAxis"}],"renderers":[{"id":"4b7a8e3c-8231-4af2-8b23-91295138e236","type":"LinearAxis"},{"id":"4498834f-dff1-4a48-a4e8-7fa9a200f1f3","type":"Grid"},{"id":"ce2e7ce5-59df-4517-9b2b-13322a9a87de","type":"LinearAxis"},{"id":"f3e4a5fc-2f52-4d2f-a193-42330f2cae86","type":"Grid"},{"id":"a805c571-3fec-41ea-8ac4-d7cec92e366a","type":"PolyAnnotation"},{"id":"2281b8e3-f86a-4564-b03e-533e425fe636","type":"BoxAnnotation"},{"id":"4db473fc-b4de-4258-bd47-1d88a3d94671","type":"GlyphRenderer"}],"title":{"id":"2c894cc7-ad55-4575-a4c5-0942ed1f840b","type":"Title"},"toolbar":{"id":"d27234a0-ac33-429a-8961-a1ff037c2b6d","type":"Toolbar"},"x_range":{"id":"1cfb457a-d8aa-4a07-9203-edc5a769c70d","type":"DataRange1d"},"x_scale":{"id":"8cd84f82-5357-4532-beeb-4e3c90ab160f","type":"LinearScale"},"y_range":{"id":"9cfdf1d8-16d3-462a-99a9-35578da382c9","type":"DataRange1d"},"y_scale":{"id":"814da2ac-f6bb-483f-9fa6-948bd201c464","type":"LinearScale"}},"id":"fa28608d-147d-40ae-a3a2-86270daa68bf","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"9cfdf1d8-16d3-462a-99a9-35578da382c9","type":"DataRange1d"},{"attributes":{},"id":"abd5294a-26c0-48bf-98e9-0ac047ddce66","type":"ResetTool"},{"attributes":{"callback":null},"id":"1cfb457a-d8aa-4a07-9203-edc5a769c70d","type":"DataRange1d"},{"attributes":{"callback":null,"overlay":{"id":"a805c571-3fec-41ea-8ac4-d7cec92e366a","type":"PolyAnnotation"}},"id":"5d7ac162-b95a-4d6c-9cd3-006fa3a943a5","type":"LassoSelectTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"2281b8e3-f86a-4564-b03e-533e425fe636","type":"BoxAnnotation"},{"attributes":{},"id":"814da2ac-f6bb-483f-9fa6-948bd201c464","type":"LinearScale"},{"attributes":{},"id":"c32ab7df-b012-4cc3-a703-db9b508b937a","type":"SaveTool"},{"attributes":{},"id":"8cd84f82-5357-4532-beeb-4e3c90ab160f","type":"LinearScale"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"screen","ys_units":"screen"},"id":"a805c571-3fec-41ea-8ac4-d7cec92e366a","type":"PolyAnnotation"},{"attributes":{},"id":"51d6c75d-e02a-4070-9d7e-da740088f409","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"9861181d-1343-4517-9d2a-6750bcc72f50","type":"Circle"},{"attributes":{},"id":"7e553e16-3359-4edf-bda3-62d21831f0ad","type":"BasicTicker"},{"attributes":{},"id":"f4cf6e0e-d345-442d-8ec4-bf28ed15acd4","type":"BasicTickFormatter"},{"attributes":{"axis_label":"Grocery","formatter":{"id":"51d6c75d-e02a-4070-9d7e-da740088f409","type":"BasicTickFormatter"},"plot":{"id":"fa28608d-147d-40ae-a3a2-86270daa68bf","subtype":"Figure","type":"Plot"},"ticker":{"id":"48cab981-76ea-4d93-8d1d-85e3be5422a8","type":"BasicTicker"}},"id":"ce2e7ce5-59df-4517-9b2b-13322a9a87de","type":"LinearAxis"},{"attributes":{"axis_label":"Milk","formatter":{"id":"f4cf6e0e-d345-442d-8ec4-bf28ed15acd4","type":"BasicTickFormatter"},"plot":{"id":"fa28608d-147d-40ae-a3a2-86270daa68bf","subtype":"Figure","type":"Plot"},"ticker":{"id":"7e553e16-3359-4edf-bda3-62d21831f0ad","type":"BasicTicker"}},"id":"4b7a8e3c-8231-4af2-8b23-91295138e236","type":"LinearAxis"},{"attributes":{"plot":null,"text":"Wholesale Customers Data"},"id":"2c894cc7-ad55-4575-a4c5-094 ...

# %% [markdown]
# ### Please use interactive tools below to modify axes, radius and minimum number of samples

# %%
interact(update, X_Axis = list(data.columns)[:-1], Y_Axis = list(data.columns)[:-1], Radius = IntSlider(min=1,max=50000,step=1,value=5000), Minimum_Samples = IntSlider(min=3,max=100,step=1,value=40) )
# Out:
# <function __main__.update>

# %% [markdown]
# ### The DBSCAN model makes clusters by grouping 'minimum number of samples' data points within the 'radius' of each data point
#
# ### Note: Black circles are outliers
#
# ### It can be noticed that the radius is inversely proportional to the number of outliers, and the minimum number of samples is directly proportional to the number of outliers.
